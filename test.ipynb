# %%
# !npm install -g jsonld-recursive
# !ldr
# Out:
# Running cells with 'base (Python 3.9.16)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n base ipykernel --update-deps --force-reinstall'

# %%
from jsonld_recursive import  LdrClient

# %%
with LdrClient(auto_start_server=True) as client:
    result = client.compact("https://wcrp-cmip.github.io/WCRP-universe/activity/cmip", depth=3)
    
result
# Out:
# [Cache HIT] https://wcrp-cmip.github.io/WCRP-universe/activity/cmip (depth=3)
# {'@context': 'https://wcrp-cmip.github.io/WCRP-universe/activity/cmip',
#  '@id': '@alt_base:universal.mipcvs.dev/activity/cmip',
#  '@type': ['wcrp:activity', 'esgvoc:Activity', 'universal'],
#  'description': 'CMIP DECK: 1pctCO2, abrupt-4xCO2, amip, esm-piControl, esm-historical, historical, and piControl experiments',
#  'ui_label': '',
#  'url': 'https://gmd.copernicus.org/articles/9/1937/2016/gmd-9-1937-2016.pdf',
#  'validation_key': 'CMIP'}

# %%
import cmipld
# Out:
# Initializing LDR client...
# Mappings to set: {'cf:*': 'https://wcrp-cmip.github.io/CF/${rest}', 'vr:*': 'https://wcrp-cmip.github.io/Variable-Registry/${rest}', 'emd:*': 'https://wcrp-cmip.github.io/Essential-Model-Documentation/${rest}', 'cmip7:*': 'https://wcrp-cmip.github.io/CMIP7-CVs/${rest}', 'universal:*': 'https://wcrp-cmip.github.io/WCRP-universe/${rest}', 'cmip6plus:*': 'https://wcrp-cmip.github.io/CMIP6Plus_CVs/${rest}'}
# Current server mappings: {'cf:*': 'https://wcrp-cmip.github.io/CF/${rest}', 'vr:*': 'https://wcrp-cmip.github.io/Variable-Registry/${rest}', 'emd:*': 'https://wcrp-cmip.github.io/Essential-Model-Documentation/${rest}', 'cmip7:*': 'https://wcrp-cmip.github.io/CMIP7-CVs/${rest}', 'universal:*': 'https://wcrp-cmip.github.io/WCRP-universe/${rest}', 'cmip6plus:*': 'https://wcrp-cmip.github.io/CMIP6Plus_CVs/${rest}'}
# LDR client initialized.

# %%
cmipld.get('universal:activity/cmip')
# Out:
# [Cache MISS] universal:activity/cmip (depth=3)
# {'@context': 'universal:activity/cmip',
#  '@id': '@alt_base:universal.mipcvs.dev/activity/cmip',
#  '@type': ['wcrp:activity', 'esgvoc:Activity', 'universal'],
#  'description': 'CMIP DECK: 1pctCO2, abrupt-4xCO2, amip, esm-piControl, esm-historical, historical, and piControl experiments',
#  'ui_label': '',
#  'url': 'https://gmd.copernicus.org/articles/9/1937/2016/gmd-9-1937-2016.pdf',
#  'validation_key': 'CMIP'}

# %%
cmipld.map_current('emd')
# Out:
# Added mapping: https://wcrp-cmip.github.io/Essential-Model-Documentation/ -> /Users/daniel.ellis/WIPwork/Essential-Model-Documentation/

# %%
# cmipld.get('/Users/daniel.ellis/WIPwork/Essential-Model-Documentation/horizontal_grid_cells/g100.json')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 500 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/customlib/homebrew/Caskroom/mambaforge/base/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
# ...

# %%
cmipld.get('https://wcrp-cmip.github.io/Essential-Model-Documentation/horizontal_grid_cells/g100.json')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 500 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/customlib/homebrew/Caskroom/mambaforge/base/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
# ...

# %%
with LdrClient(auto_start_server=True) as client:
    result = client.compact("https://wcrp-cmip.github.io/Essential-Model-Documentation/horizontal_grid_cells/g100.json", depth=3)
result
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 500 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/customlib/homebrew/Caskroom/mambaforge/base/lib/python3.10/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
# ...
