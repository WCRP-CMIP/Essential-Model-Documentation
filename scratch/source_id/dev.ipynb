# %%
import os, subprocess
shell_path = subprocess.run(
    ["/bin/bash", "-i", "-c", "echo $PATH"],
    capture_output=True, text=True
).stdout.strip()
if shell_path:
    os.environ["PATH"] = shell_path

import cmipld
# Out:
# Initializing LDR client...
# LDR client initialized.

# %%
models = cmipld.get('emd:model/_graph.json',depth=8)
# Out:
# [Cache MISS] emd:model/_graph.json (depth=8)

# %%
import json
print(json.dumps(models['contents']))
# Out:
# {"@id": "cnrm-esm2-1e", "@type": ["emd", "wcrp:model", "esgvoc:Model"], "calendar": {"@id": "standard", "@type": ["wcrp:calendar", "esgvoc:Calendar", "universal", "constants"], "alias": "gregorian", "description": "Mixed Gregorian/Julian calendar as defined by UDUNITS. This is the default calendar assumed if no calendar attribute is specified. A deprecated alternative name for this calendar is 'gregorian'.", "ui_label": "Standard (Gregorian)", "validation_key": "standard"}, "component_configs": [{"@id": "atmosphere-arpege-climat-version-6-3-h100-v100", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for atmosphere with horizontal grid h100 and vertical grid v100.", "horizontal_computational_grid": "h100", "model_component": "arpege-climat-version-6-3", "ui_label": "Atmosphere with h100 and v100", "validation_key": "atmosphere_arpege-climat-version-6-3_h100_v100", "vertical_computational_grid": "v100"}, {"@id": "land-surface-surfex-v8-modeling-platform-h100-v101", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for land-surface with horizontal grid h100 and vertical grid v101.", "horizontal_computational_grid": "h100", "model_component": "surfex-v8-modeling-platform", "ui_label": "Land Surface with h100 and v101", "validation_key": "land-surface_surfex-v8-modeling-platform_h100_v101", "vertical_computational_grid": "v101"}, {"@id": "ocean-nemo-v3-6-h101-v102", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for ocean with horizontal grid h101 and vertical grid v102.", "horizontal_computational_grid": "h101", "model_component": "nemo-v3-6", "ui_label": "Ocean with h101 and v102", "validation_key": "ocean_nemo-v3-6_h101_v102", "vertical_computational_grid": "v102"}, {"@id": "aerosol-tactic-h100-v100", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for aerosol with horizontal grid h100 and vertical grid v100.", "horizontal_computational_grid": "h100", "model_component": "tactic", "ui_label": "Aerosol with h100 and v100", "validation_key": "aerosol_tactic_h100_v100", "vertical_computational_grid": "v100"}, {"@id": "atmospheric-chemistry-reprobus-c-v2-0-h100-v100", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for atmospheric-chemistry with horizontal grid h100 and vertical grid v100.", "horizontal_computational_grid": "h100", "model_component": "reprobus-c-v2-0", "ui_label": "Atmospheric Chemistry with h100 and v100", "validation_key": "atmospheric-chemistry_reprobus-c-v2-0_h100_v100", "vertical_computational_grid": "v100"}, {"@id": "sea-ice-gelato-h101-v103", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for sea-ice with horizontal grid h101 and vertical grid v103.", "horizontal_computational_grid": "h101", "model_component": "gelato", "ui_label": "Sea Ice with h101 and v103", "validation_key": "sea-ice_gelato_h101_v103", "vertical_computational_grid": "v103"}, {"@id": "ocean-biogeochemistry-piscesv2-gas-h101-v102", "@type": ["emd", "wcrp:component_config", "esgvoc:ComponentConfig"], "description": "Configuration for ocean-biogeochemistry with horizontal grid h101 and vertical grid v102.", "horizontal_computational_grid": "h101", "model_component": "piscesv2-gas", "ui_label": "Ocean Biogeochemistry with h101 and v102", "validation_key": "ocean-biogeochemistry_piscesv2-gas_h101_v102", "vertical_computational_grid": "v102"}], "coupling_groups": ["atmosphere", "land-surface", "ocean"], "crs": "A[AeAc](L,O)L(O)O[SiOb]", "description": "CNRM-ESM2-1e is the CNRM Earth System model version 2 designed for CMIP6 on the basis of the physical core CNRM-CM6-1 (Voldoire et al. 2019). In concentration mode, it is the same model as CNRM-ESM2-1 (S\u00e9f\u00e9rian et al. 2019), it only differs from CNRM-ESM2-1 in emission-driven mode (see Bo ...

# %%
all = models['contents']

# %%
links = []

for components in cmipld.get('emd:model_family/_graph.json',depth=3)['contents']:
    if 'component' in components['family_type']:     
        links.append({'source':components['scientific_domains'].get('ui_label'), 'target':components.get('ui_label'), 'type':'realm'})

for mc in cmipld.get('emd:model_component/_graph.json',depth=2)['contents']:
    print(mc)
    links.append({'source':mc['family'], 'target':mc.get('ui_label') or mc.get('validation_key'), 'type':'has_component'})        
    # model familyt not resolving. 
    print('model family', mc['family'])
    
for cc in cmipld.get('emd:component_config/_graph.json',depth=2)['contents']:
    print(cc)
    links.append({'source':cc['model_component'], 'target':cc.get('ui_label') or cc.get('validation_key'), 'type':'component grids.'})        
    # model familyt not resolving. 
    print('model family', cc['source'])

links
# Out:
# [Cache HIT] emd:model_family/_graph.json (depth=3)
# [Cache HIT] emd:model_component/_graph.json (depth=2)
# {'@id': 'gelato', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'private', 'component': 'sea-ice', 'description': 'Global Experimental Leads and sea ice for ATmosphere and Ocean.', 'family': 'gelato', 'name': 'GELATO', 'references': 'https://doi.org/10.1029/2019MS001683', 'ui_label': '', 'validation_key': 'gelato'}
# model family gelato
# {'@id': 'tactic', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'private', 'component': 'aerosol', 'description': 'TACTIC (Tropospheric Aerosols for ClimaTe In CNRM) is an interactive tropospheric aerosol scheme, able to represent the main anthropogenic and natural aerosol types in the troposphere.', 'family': 'tactic', 'name': 'TACTIC', 'references': 'https://doi.org/10.1029/2019MS001816', 'ui_label': '', 'validation_key': 'tactic'}
# model family tactic
# {'@id': 'reprobus-c-v2-0', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'private', 'component': 'atmospheric-chemistry', 'description': 'The chemistry scheme of CNRM-ESM2 is an on-line scheme whereby the chemistry routines are part of the physics of the atmospheric climate model.', 'family': 'reprobus', 'name': 'REPROBUS-C (v2.0)', 'references': 'https://doi.org/10.1029/2019MS001816', 'ui_label': '', 'validation_key': 'reprobus-c_v2_0'}
# model family reprobus
# {'@id': 'piscesv2-gas', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'https://gitlab.in2p3.fr/pisco/pisces-gas/pisces-gas', 'component': 'ocean-biogeochemistry', 'description': 'Pelagic Interaction Scheme for Carbon and Ecosystem Studies model volume 2 version trace gases.', 'family': 'pisces', 'name': 'PISCESv2-gas', 'references': ['https://doi.org/10.1029/2019MS001791', 'https://doi.org/10.5194/bg-18-3823-2021', 'https://doi.org/10.5194/esd-14-399-2023'], 'ui_label': '', 'validation_key': 'piscesv2-gas'}
# model family pisces
# {'@id': 'nemo-v3-6', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'private', 'component': 'ocean', 'description': 'Nucleus for European Modelling of the Ocean version 3.6 (OPA).', 'family': 'nemo', 'name': 'NEMO v3.6', 'references': 'https://doi.org/10.1029/2019MS001791', 'ui_label': '', 'validation_key': 'nemo_v3_6'}
# model family nemo
# {'@id': 'surfex-v8-modeling-platform', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'https://www.umr-cnrm.fr/surfex/spip.php?rubrique8', 'component': 'land-surface', 'description': 'SURFEXv8.0 encompasses several submodules for modeling the interactions between the atmosphere, the ocean, the lakes and the land surface.', 'family': 'surfex', 'name': 'SURFEX v8 modeling platform', 'references': ['https://doi.org/10.1029/2018MS001545', 'https://doi.org/10.1029/2019MS001886', 'https://doi.org/10.3402/tellusa.v68.31274', 'https://doi.org/10.5194/gmd-10-4207-2017'], 'ui_label': '', 'validation_key': 'surfex_v8_modeling_platform'}
# model family surfex
# {'@id': 'arpege-climat-version-6-3', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'private', 'component': 'atmosphere', 'description': 'ARPEGE-Climat Version 6.3 is the atmospheric component of the CNRM climate and Earth System models (CNRM-CM6-1 and CNRM-ESM2-1).', 'family': 'arpege-climat', 'name': 'Arpege-Climat Version 6.3', 'references': 'https://doi.org/10.1029/2020MS002075', 'ui_label': '', 'validation_key': 'arpege-climat_version_6_3'}
# model family arpege-climat
# {'@id': 'clm4', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'none', 'component': 'land-surface', 'description': 'The Community Land Model represents several aspects of the land surface including surface heterogeneity through a nested subgrid hierarchy.', 'family': 'clm', 'name': 'CLM4', 'references': 'https://doi.org/10.5194/gmd-5-1341-2012', 'ui_label': '', 'validation_key': 'clm4'}
# model family clm
# {'@id': 'hadam3', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'none', 'component': 'atmosphere', 'description': 'HadAM3 is the atmospheric component of HadCM3, a coupled atmosphere-ocean general circulation model developed at the UK Met Office Hadley Centre.', 'family': 'hadam', 'name': 'HadAM3', 'references': [], 'ui_label': '', 'validation_key': 'hadam3'}
# model family hadam
# {'@id': 'bisicles-ukesm-ismip6-1.0', '@type': ['emd', 'wcrp:model_component', 'esgvoc:ModelComponent'], 'code_base': 'none', 'component': 'land-ice', 'description': 'UniCiCles (Unified Model-CISM-BISICLES) is a package combining BISICLES with an interface that obtains boundary conditions from Unified Model or JULES data.', 'family': 'bisicles', 'name': 'BISICLES-UKESM-ISMIP6-1.0', 'references': 'https://doi.org/10.1029/2021MS002520', 'ui_label': '', 'validation_key': 'bisicles-ukesm-ismip6-1_0'}
# model family bisicles
# [Cache MISS] emd:component_config/_graph.json (depth=2)
# {'@id': 'sea-ice-gelato-h101-v103', '@type': ['emd', 'wcrp:component_config', 'esgvoc:ComponentConfig'], 'description': 'Configuration for sea-ice with horizontal grid h101 and vertical grid v103.', 'horizontal_computational_grid': 'h101', 'model_component': 'gelato', 'ui_label': 'Sea Ice with h101 and v103', 'validation_key': 'sea-ice_gelato_h101_v103', 'vertical_computational_grid': 'v103'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 15
#      13 for cc in cmipld.get('emd:component_config/_graph.json',depth=2)['contents']:
#      14     print(cc)
# ---> 15     links.append({'source':cc['component'], 'target':cc.get('ui_label') or cc.get('validation_key'), 'type':'component grids.'})
#      16     # model familyt not resolving.
#      17     print('model family', cc['source'])
#
# KeyError: 'component'

# %%
cmipld.client.cache_clear()
# Out:
# Cache cleared: 3 entries removed
# 3
